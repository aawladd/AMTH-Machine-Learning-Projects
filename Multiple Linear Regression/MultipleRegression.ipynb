# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('kc_house_data.csv')
df.head(10)
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
y = df['price']
y
# Out:
# 0        221900.0
# 1        538000.0
# 2        180000.0
# 3        604000.0
# 4        510000.0
#            ...
# 21608    360000.0
# 21609    400000.0
# 21610    402101.0
# 21611    400000.0
# 21612    325000.0
# Name: price, Length: 21613, dtype: float64

# %%
X = df.drop(columns='price')

# %%
X
# Out:
#                id             date  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  20141013T000000         3       1.00         1180
# 1      6414100192  20141209T000000         3       2.25         2570
# 2      5631500400  20150225T000000         2       1.00          770
# 3      2487200875  20141209T000000         4       3.00         1960
# 4      1954400510  20150218T000000         3       2.00         1680
# ...           ...              ...       ...        ...          ...
# 21608   263000018  20140521T000000         3       2.50         1530
# 21609  6600060120  20150223T000000         4       2.50         2310
# 21610  1523300141  20140623T000000         2       0.75         1020
# 21611   291310100  20150116T000000         3       2.50         1600
# 21612  1523300157  20141015T000000         2       0.75         1020
#
#        sqft_lot  floors  waterfront  view  condition  grade  sqft_above  \
# ...

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   bedrooms       21613 non-null  int64
#  3   bathrooms      21613 non-null  float64
#  4   sqft_living    21613 non-null  int64
#  5   sqft_lot       21613 non-null  int64
#  6   floors         21613 non-null  float64
#  7   waterfront     21613 non-null  int64
#  8   view           21613 non-null  int64
#  9   condition      21613 non-null  int64
#  10  grade          21613 non-null  int64
#  11  sqft_above     21613 non-null  int64
#  12  sqft_basement  21613 non-null  int64
#  13  yr_built       21613 non-null  int64
#  14  yr_renovated   21613 non-null  int64
#  15  zipcode        21613 non-null  int64
#  16  lat            21613 non-null  float64
# ...

# %%
X = df.to_numpy()
X
# Out:
# array([[7129300520, '20141013T000000', 221900.0, ..., -122.257, 1340,
#         5650],
#        [6414100192, '20141209T000000', 538000.0, ..., -122.319, 1690,
#         7639],
#        [5631500400, '20150225T000000', 180000.0, ..., -122.233, 2720,
#         8062],
#        ...,
#        [1523300141, '20140623T000000', 402101.0, ..., -122.299, 1020,
#         2007],
#        [291310100, '20150116T000000', 400000.0, ..., -122.069, 1410,
#         1287],
#        [1523300157, '20141015T000000', 325000.0, ..., -122.299, 1020,
#         1357]], dtype=object)

# %%
X.shape
# Out:
# (21613, 21)

# %%
y = y.to_numpy()

# %%
y.shape
# Out:
# (21613,)

# %% [markdown]
# <h1>OLS Regression in Matrix Form</h1>
#
# $y = Xb+e$</b>
#
# $ e = y - Xb$
#
# $\sum e_i^{2} = e'e$
#
# $e'e = (y-Xb)'(y-Xb)$
# $    = y'y - 2b'X'y+b'X'Xb$<br>
#
# $\frac{\partial e'e}{\partial b} = -2X'y + 2X'Xb=0$<br>
#
# $\therefore (X'X)b=X'y$ <br>
#
# $\therefore b = (X'X)^{-1}X'y$

# %%
#b = np.linalg.inv(X.T @ X) @ X.T @ y

# %% [markdown]
# ###  In this Method Size of data Matter(Dead Kernel)

# %% [markdown]
# # Trying With New Data Sets

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Real estate.csv')
df.head(10)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
# 2   3             2013.583          13.3
# 3   4             2013.500          13.3
# 4   5             2012.833           5.0
# 5   6             2012.667           7.1
# 6   7             2012.667          34.5
# 7   8             2013.417          20.3
# 8   9             2013.500          31.7
# 9  10             2013.417          17.9
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
# 2                               561.98450                                5
# 3                               561.98450                                5
# 4                               390.56840                                5
# ...

# %%
df=df.drop(columns='No')

# %%
df.mean()
# Out:
# X1 transaction date                       2013.148971
# X2 house age                                17.712560
# X3 distance to the nearest MRT station    1083.885689
# X4 number of convenience stores              4.094203
# X5 latitude                                 24.969030
# X6 longitude                               121.533361
# Y house price of unit area                  37.980193
# dtype: float64

# %%
df = df - df.mean()

# %%
df.mean()
# Out:
# X1 transaction date                       1.043502e-13
# X2 house age                             -9.267949e-16
# X3 distance to the nearest MRT station   -1.362045e-13
# X4 number of convenience stores           4.290717e-18
# X5 latitude                               1.664798e-15
# X6 longitude                             -2.474886e-14
# Y house price of unit area                1.270052e-15
# dtype: float64

# %%
new_col = 1
df.insert(loc=0, column='New', value=new_col)
df.head(20)
# Out:
#     New  X1 transaction date  X2 house age  \
# 0     1            -0.231971      14.28744
# 1     1            -0.231971       1.78744
# 2     1             0.434029      -4.41256
# 3     1             0.351029      -4.41256
# 4     1            -0.315971     -12.71256
# 5     1            -0.481971     -10.61256
# 6     1            -0.481971      16.78744
# 7     1             0.268029       2.58744
# 8     1             0.351029      13.98744
# 9     1             0.268029       0.18744
# 10    1            -0.065971      17.08744
# 11    1             0.184029     -11.41256
# 12    1            -0.231971      -4.71256
# 13    1            -0.481971       2.68744
# 14    1             0.351029      -4.51256
# 15    1             0.434029      17.98744
# 16    1             0.101029     -17.71256
# 17    1            -0.398971      -0.01256
# 18    1             0.268029      -0.81256
# 19    1            -0.481971     -16.21256
#
# ...

# %%
y = df['Y house price of unit area']

# %%
y
# Out:
# 0      -0.080193
# 1       4.219807
# 2       9.319807
# 3      16.819807
# 4       5.119807
#          ...
# 409   -22.580193
# 410    12.019807
# 411     2.619807
# 412    14.519807
# 413    25.919807
# Name: Y house price of unit area, Length: 414, dtype: float64

# %%
y = y.to_numpy()

# %%
y.shape
# Out:
# (414,)

# %%
y.T
# Out:
# array([ -0.08019324,   4.21980676,   9.31980676,  16.81980676,
#          5.11980676,  -5.88019324,   2.31980676,   8.71980676,
#        -19.18019324, -15.88019324,   3.41980676,  20.11980676,
#          1.31980676, -14.18019324,  -3.68019324,  12.51980676,
#         32.11980676,  -0.58019324,   4.31980676,   9.71980676,
#         -8.68019324,  13.61980676, -13.38019324,   9.91980676,
#          0.81980676, -10.98019324,  18.21980676,  -4.38019324,
#          9.01980676,  19.11980676, -15.88019324, -12.98019324,
#         -3.78019324,  11.31980676,  17.11980676, -10.68019324,
#        -15.08019324, -12.68019324,   9.71980676,   8.21980676,
#        -22.08019324, -19.78019324,  -3.28019324,  -3.88019324,
#         15.91980676,   0.31980676,   4.01980676,  23.51980676,
#        -24.58019324, -24.78019324,   6.21980676, -17.28019324,
#        -10.98019324,   0.91980676,  13.71980676, -24.28019324,
#          3.91980676,  15.51980676, -15.38019324,   4.41980676,
# ...

# %%
X = df.drop(columns='Y house price of unit area')

# %%
X = X.to_numpy()

# %%
X.shape
# Out:
# (414, 7)

# %%
b = np.linalg.inv(X.T @ X) @ X.T @ y

# %%
b
# Out:
# array([-1.21916366e-12,  5.14622746e+00, -2.69695448e-01, -4.48746107e-03,
#         1.13327690e+00,  2.25472976e+02, -1.24236012e+01])

# %%
predict = X[44]@b.T
predict
# Out:
# 9.69014169678615

# %%
df.loc[44]
# Out:
# New                                         1.000000
# X1 transaction date                         0.434029
# X2 house age                              -15.012560
# X3 distance to the nearest MRT station   -550.409489
# X4 number of convenience stores            -0.094203
# X5 latitude                                 0.005420
# X6 longitude                                0.014289
# Y house price of unit area                 15.919807
# Name: 44, dtype: float64

# %% [markdown]
# # Testing With Dummy Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('mlr07.xls', engine='xlrd')
df.head(10)
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'iso-8859-1'
#      X1   X2    X3    X4   X5
# 0   8.0   78   284   9.1  109
# 1   9.3   68   433   8.7  144
# 2   7.5   70   739   7.2  113
# 3   8.9   96  1792   8.9   97
# 4  10.2   74   477   8.3  206
# 5   8.3  111   362  10.9  124
# 6   8.8   77   671  10.0  152
# 7   8.8  168   636   9.1  162
# 8  10.7   82   329   8.7  150
# 9  11.7   89   634   7.6  134

# %%
df = df - df.mean()

# 13    1 -33.09434    13.207547  0.064151   71.358491
# 14    1  13.90566    96.207547 -0.735849   18.358491
# 15    1  28.90566  -244.792453  1.764151   47.358491
# 16    1  -4.09434   767.207547  0.264151   75.358491
# ...

# %%
y = y.to_numpy()
y
# Out:
# array([-1.30566041e+00, -5.66021872e-03, -1.80566041e+00, -4.05660791e-01,
#         8.94339400e-01, -1.00566022e+00, -5.05660219e-01, -5.05660219e-01,
#         1.39433940e+00,  2.39433940e+00, -8.05660410e-01, -1.00566022e+00,
#        -1.10566060e+00, -1.40566031e+00,  9.94339780e-01, -1.90566031e+00,
#         2.94339971e-01, -5.66021872e-03,  1.29433997e+00,  3.94339399e-01,
#         2.29433997e+00, -1.20566003e+00,  4.94339781e-01, -1.90566031e+00,
#         9.43392093e-02,  1.89433940e+00, -2.05660029e-01,  1.19433959e+00,
#         2.59433921e+00, -9.05660791e-01, -4.30566041e+00,  4.94339781e-01,
#         4.94339781e-01,  1.49433978e+00,  7.94339970e-01,  1.59433921e+00,
#        -1.05660601e-01, -1.00566022e+00, -2.00566022e+00,  9.43392093e-02,
#         9.43392093e-02,  4.94339781e-01, -5.70566050e+00, -9.05660791e-01,
#         1.49433978e+00,  7.94339970e-01, -3.05660410e-01,  6.94339590e-01,
# ...

# %%
X = X.to_numpy()

# %%
X
# Out:
# array([[ 1.00000000e+00, -3.80943396e+01, -3.05792453e+02,
#         -3.35848611e-01, -1.64150943e+00],
#        [ 1.00000000e+00, -4.80943396e+01, -1.56792453e+02,
#         -7.35849183e-01,  3.33584906e+01],
#        [ 1.00000000e+00, -4.60943396e+01,  1.49207547e+02,
#         -2.23584918e+00,  2.35849057e+00],
#        [ 1.00000000e+00, -2.00943396e+01,  1.20220755e+03,
#         -5.35849373e-01, -1.36415094e+01],
#        [ 1.00000000e+00, -4.20943396e+01, -1.12792453e+02,
#         -1.13584880e+00,  9.53584906e+01],
#        [ 1.00000000e+00, -5.09433962e+00, -2.27792453e+02,
#          1.46415063e+00,  1.33584906e+01],
#        [ 1.00000000e+00, -3.90943396e+01,  8.12075472e+01,
#          5.64151008e-01,  4.13584906e+01],
#        [ 1.00000000e+00,  5.19056604e+01,  4.62075472e+01,
#         -3.35848611e-01,  5.13584906e+01],
#        [ 1.00000000e+00, -3.40943396e+01, -2.60792453e+02,
#         -7.35849183e-01,  3.93584906e+01],
# ...

# %%
b = np.linalg.inv(X.T @ X) @ X.T @ y
b
# Out:
# array([-4.39051160e-16,  7.39161503e-03,  5.83715656e-04, -3.30230237e-01,
#        -9.46288488e-03])

# %%
predict = X[44]@b.T
predict
# Out:
# 0.5779008484531195

# %%
df.loc[44]
# Out:
# X1     1.494340
# X2     2.905660
# X3   -49.792453
# X4    -0.235849
# X5   -53.641509
# Name: 44, dtype: float64
